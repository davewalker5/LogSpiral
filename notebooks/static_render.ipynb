# %%
# %run shell_pipeline.ipynb

# %%
PRESETS = {
    "ammonite": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "annulated-orthocone": {
        "iso": 1.25,
        "top": 1.5,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "crioceratite": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "cyrtocone": {
        "iso": 1.25,
        "top": 1.5,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "flared": {
        "iso": 1.0,
        "top": 1.2,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "nautilus": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "orthocone": {
        "iso": 1.25,
        "top": 1.5,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "ramshorn": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "serpenticone": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "smooth-nautilus": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    },
    "turritella": {
        "iso": 1.0,
        "top": 1.0,
        "aperture": 1.0,
        "presentation": 1.0
    }
}

# %%
NAME="annulated-orthocone"
views = PRESETS[NAME] if NAME in PRESETS.keys() else None
render_static(NAME, views)
